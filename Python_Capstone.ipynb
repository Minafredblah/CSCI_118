# %%
import pandas as pd
import matplotlib.pyplot as mp
import numpy as np
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-70c4a34d-546a-4ccd-bd67-b2096de9bdf4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-70c4a34d-546a-4ccd-bd67-b2096de9bdf4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded["games.csv"]))
df.head()
# Out:
#                publisher                                 title releaseDate  \
# 0     Nintendo Gradiente  The Legend of Zelda: Ocarina of Time       36122
# 1                  Namco                           SoulCalibur       36411
# 2  Rockstar Games,Capcom                   Grand Theft Auto IV       39567
# 3               Nintendo                    Super Mario Galaxy       39398
# 4          Nintendo iQue                  Super Mario Galaxy 2       40321
#
#   rating             genres                             platforms metascore  \
# 0      E  Open-World Action                           Nintendo 64        99
# 1      T        3D Fighting  Dreamcast iOS (iPhone/iPad) Xbox 360        98
# 2      M  Open-World Action             PlayStation 3 Xbox 360 PC        98
# 3      E      3D Platformer                                   Wii        97
# 4      E      3D Platformer                                   Wii        97
#
# ...

# %%
df2 = df[["title","developer","metascore", "userscore"]]
df2.head()
# Out:
#                                   title            developer metascore  \
# 0  The Legend of Zelda: Ocarina of Time             Nintendo        99
# 1                           SoulCalibur                Namco        98
# 2                   Grand Theft Auto IV       Rockstar North        98
# 3                    Super Mario Galaxy             Nintendo        97
# 4                  Super Mario Galaxy 2  Nintendo EAD Tokyo         97
#
#   userscore
# 0        91
# 1        78
# 2        83
# 3        91
# 4        90

# %%
nin = df2[(df2["developer"]=="Nintendo")]
nin.head()
# Out:
#                                         title developer metascore userscore
# 0        The Legend of Zelda: Ocarina of Time  Nintendo        99        91
# 3                          Super Mario Galaxy  Nintendo        97        91
# 5     The Legend of Zelda: Breath of the Wild  Nintendo        97        89
# 12                        Super Mario Odyssey  Nintendo        97        89
# 28  The Legend of Zelda: Tears of the Kingdom  Nintendo        96        88

# %%
ubi = df2[(df2["developer"]=="Ubisoft")]
seg = df2[(df2["developer"]=="Sega")]
roc = df2[(df2["developer"]=="Rockstar Games")]

# %%
mp.figure(figsize = (10,6))
mp.scatter(nin["title"],nin["metascore"])
mp.show()

# %%
mp.figure(figsize = (10,6))
mp.scatter(ubi["title"],ubi["metascore"])
mp.show()

# %%
mp.figure(figsize = (10,6))
mp.scatter(seg["title"],seg["metascore"])
mp.show()

# %%
mp.figure(figsize = (10,6))
mp.scatter(roc["title"],roc["metascore"])
mp.show()
