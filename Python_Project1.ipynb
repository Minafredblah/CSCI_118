# %%
import pandas as pd
import matplotlib as mp

# %%
df = pd.read_csv("https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv")
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
#I think what I did here was create variables for all of the boroughs that will be used for the data set
dfx = df[(df['School DBN'].str.contains('X'))&(df['Mean Score']!="s")&(df['Regents Exam']=="Living Environment")]
dfk = df[(df['School DBN'].str.contains('K'))&(df['Mean Score']!="s")&(df['Regents Exam']=="Living Environment")]
dfq = df[(df['School DBN'].str.contains('Q'))&(df['Mean Score']!="s")&(df['Regents Exam']=="Living Environment")]
dfm = df[(df['School DBN'].str.contains('M'))&(df['Mean Score']!="s")&(df['Regents Exam']=="Living Environment")]
dfr = df[(df['School DBN'].str.contains('R'))&(df['Mean Score']!="s")&(df['Regents Exam']=="Living Environment")]

# %%
#Change all Mean Scores to floats so we can plot them (Question: Why is dfx the only one that doesn't work???)
#dfx = dfx["Mean Score"].astype(float)
dfk = dfk["Mean Score"].astype(float)
dfq = dfq["Mean Score"].astype(float)
dfm = dfm["Mean Score"].astype(float)
dfr = dfr["Mean Score"].astype(float)

# %%
dfq.dtypes
# Out:
# dtype('float64')

# %%
#Make a plot for Manhattan (Question: How to customize this a little bit (Add overlap and such))
dfm.plot.hist(bins = 10, orientation = "vertical",cumulative = False)
dfm.describe()
# Out:
# count    3733.000000
# mean       70.350147
# std         9.792154
# min        39.600000
# 25%        63.300000
# 50%        69.900000
# 75%        76.800000
# max        96.800000
# Name: Mean Score, dtype: float64

# %%
#Make a plot for queens mean scores
dfq.plot.hist(bins = 10,orientation = "vertical",cumulative = False)
dfq.describe()
# Out:
# count    3600.000000
# mean       73.013889
# std         9.995561
# min        36.500000
# 25%        65.800000
# 50%        72.700000
# 75%        80.500000
# max        94.300000
# Name: Mean Score, dtype: float64

# %% [markdown]
# It seems like Queens has a slightly higher mean score than Manhattan does. This does not include which year each score was made in, so there is definetely some more detail that needs to be included to be useful. This dataset was a mess and therefore I used the method of destroying all the empty data before analyzing, so this data is absolutely not conclusive.
